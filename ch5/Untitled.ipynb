# %%
import pickle
import numpy as np
import os

# %%
# Preditiction for a single customer
def single_pred(customer, dv, model):
    X = dv.transform([customer])
    y_pred = model.predict_proba(X)[:, 1]
    return y_pred[0]

# Paths
filepath_model = 'pipeline_v1.bin'

# Load model
if os.path.exists(filepath_model):
    with open(filepath_model, 'rb') as f_model:
        model = pickle.load(f_model)
else:
    print(f"File {filepath_model} not found.")

customer = {
    "lead_source": "paid_ads",
    "number_of_courses_viewed": 2,
    "annual_income": 79276.0
}
pred = single_pred(customer, dv, model)

print('prediction: %.3f' % pred)
if pred >= 0.5:
    print('Get Credit: High')
else:
    print('Get Credit: Low')
# Out:
# File dv.bin not found.
# File model1.bin not found.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 26
#      23     print(f"File {filepath_model} not found.")
#      25 customer = {"job": "retired", "duration": 445, "poutcome": "success"}
# ---> 26 pred = single_pred(customer, dv, model)
#      28 print('prediction: %.3f' % pred)
#      29 if pred >= 0.5:
#
# NameError: name 'dv' is not defined

# %%
import pickle

# Load the saved pipeline
with open('pipeline_v1.bin', 'rb') as f:
    model = pickle.load(f)

# Record to score
record = {
    "lead_source": "paid_ads",
    "number_of_courses_viewed": 2,
    "annual_income": 79276.0
}

# Get probability for class 1 (converted)
prob = model.predict_proba([record])[0, 1]

print(f"Conversion probability: {prob:.3f}")
# Out:
# Conversion probability: 0.534
